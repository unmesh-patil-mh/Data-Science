# %%
import pandas as pd

# %%
db = pd.read_csv("C:\\Users\\LOQ\\Downloads\\Iris.csv")

# %%
db
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      2.0            4.9           3.0            1.4           0.2
# 2      NaN            4.7           3.2            1.3           0.2
# 3      NaN            4.6           3.1            1.5           0.2
# 4      NaN            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
from sklearn import preprocessing

# %%
db.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0  1.0            5.1           3.5            1.4           0.2  Iris-setosa
# 1  2.0            4.9           3.0            1.4           0.2  Iris-setosa
# 2  NaN            4.7           3.2            1.3           0.2  Iris-setosa
# 3  NaN            4.6           3.1            1.5           0.2  Iris-setosa
# 4  NaN            5.0           3.6            1.4           0.2  Iris-setosa

# %%
min_max_scaler=preprocessing.MinMaxScaler()

# %%
min_max_scaler
# Out:
# MinMaxScaler()

# %%
x = db.iloc[:,:4]

# %%
x
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0      1.0            5.1           3.5            1.4
# 1      2.0            4.9           3.0            1.4
# 2      NaN            4.7           3.2            1.3
# 3      NaN            4.6           3.1            1.5
# 4      NaN            5.0           3.6            1.4
# ..     ...            ...           ...            ...
# 145  146.0            6.7           3.0            5.2
# 146  147.0            6.3           2.5            5.0
# 147  148.0            6.5           3.0            5.2
# 148  149.0            6.2           3.4            5.4
# 149  150.0            5.9           3.0            5.1
#
# [150 rows x 4 columns]

# %%
x_scaled = min_max_scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[0.        , 0.22222222, 0.625     , 0.06779661],
#        [0.00671141, 0.16666667, 0.41666667, 0.06779661],
#        [       nan, 0.11111111, 0.5       , 0.05084746],
#        [       nan, 0.08333333, 0.45833333, 0.08474576],
#        [       nan, 0.19444444, 0.66666667, 0.06779661],
#        [       nan, 0.30555556, 0.79166667, 0.11864407],
#        [       nan, 0.08333333, 0.58333333, 0.06779661],
#        [       nan, 0.19444444, 0.58333333, 0.08474576],
#        [0.05369128, 0.02777778, 0.375     , 0.06779661],
#        [0.06040268, 0.16666667, 0.45833333, 0.08474576],
#        [0.06711409, 0.30555556, 0.70833333, 0.08474576],
#        [0.0738255 , 0.13888889, 0.58333333, 0.10169492],
#        [0.08053691, 0.13888889, 0.41666667, 0.06779661],
#        [0.08724832, 0.        , 0.41666667, 0.01694915],
#        [0.09395973, 0.41666667, 0.83333333, 0.03389831],
#        [0.10067114, 0.38888889, 1.        , 0.08474576],
# ...

# %%
db_normalized = pd.DataFrame(x_scaled)

# %%
db_normalized
# Out:
#             0         1         2         3
# 0    0.000000  0.222222  0.625000  0.067797
# 1    0.006711  0.166667  0.416667  0.067797
# 2         NaN  0.111111  0.500000  0.050847
# 3         NaN  0.083333  0.458333  0.084746
# 4         NaN  0.194444  0.666667  0.067797
# ..        ...       ...       ...       ...
# 145  0.973154  0.666667  0.416667  0.711864
# 146  0.979866  0.555556  0.208333  0.677966
# 147  0.986577  0.611111  0.416667  0.711864
# 148  0.993289  0.527778  0.583333  0.745763
# 149  1.000000  0.444444  0.416667  0.694915
#
# [150 rows x 4 columns]

# %%
db['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
label_encoder
# Out:
# LabelEncoder()

# %%
db['Species']=label_encoder.fit_transform(db['Species'])

# %%
db['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
one_hot_db = pd.get_dummies(db,columns=["Species"],prefix='Species',drop_first=True)

# %%
one_hot_db
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      2.0            4.9           3.0            1.4           0.2
# 2      NaN            4.7           3.2            1.3           0.2
# 3      NaN            4.6           3.1            1.5           0.2
# 4      NaN            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#      Species_1  Species_2
# 0        False      False
# 1        False      False
# 2        False      False
# 3        False      False
# ...
