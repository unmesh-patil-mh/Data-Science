# %% [markdown]
# Prac3
#
# April 1, 2026
#
# > \[1\]: **import pandas as pd**
# > \[2\]: **import numpy as np**
# > \[3\]: **import statistics as st**
# > \[4\]: df = pd.read_csv("Iris.csv")
# > \[5\]:print(df.shape)
#
# (150, 6)
# \[57\]:print(df.info())
#
# <table>
# <colgroup>
# <col style="width: 25%" />
# <col style="width: 25%" />
# <col style="width: 25%" />
# <col style="width: 25%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th colspan="4">&lt;class 'pandas.core.frame.DataFrame'&gt;<br />
# RangeIndex: 150 entries, 0 to 149<br />
# Data columns (total 6 columns):</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>#</td>
# <td><blockquote>
# <p>Column</p>
# </blockquote></td>
# <td>Non-Null Count</td>
# <td><blockquote>
# <p>Dtype</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>---</td>
# <td><blockquote>
# <p>------</p>
# </blockquote></td>
# <td>--------------</td>
# <td><blockquote>
# <p>-----</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>0</td>
# <td><blockquote>
# <p>Id</p>
# </blockquote></td>
# <td><blockquote>
# <p>150 non-null</p>
# </blockquote></td>
# <td><blockquote>
# <p>int64</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>1</td>
# <td>SepalLengthCm</td>
# <td><blockquote>
# <p>150 non-null</p>
# </blockquote></td>
# <td><blockquote>
# <p>float64</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>2</td>
# <td><blockquote>
# <p>SepalWidthCm</p>
# </blockquote></td>
# <td><blockquote>
# <p>150 non-null</p>
# </blockquote></td>
# <td><blockquote>
# <p>float64</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>3</td>
# <td>PetalLengthCm</td>
# <td><blockquote>
# <p>150 non-null</p>
# </blockquote></td>
# <td><blockquote>
# <p>float64</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>4</td>
# <td><blockquote>
# <p>PetalWidthCm</p>
# </blockquote></td>
# <td><blockquote>
# <p>150 non-null</p>
# </blockquote></td>
# <td><blockquote>
# <p>float64</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>5</td>
# <td><blockquote>
# <p>Species</p>
# </blockquote></td>
# <td><blockquote>
# <p>150 non-null</p>
# </blockquote></td>
# <td><blockquote>
# <p>object</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td colspan="4">dtypes: float64(4), int64(1), object(1)<br />
# memory usage: 7.2+ KB<br />
# None</td>
# </tr>
# </tbody>
# </table>
#
# \[58\]: df.mean(numeric_only = **True** )
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>[58]: Id</p>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>SepalLengthCm SepalWidthCm<br />
# PetalLengthCm PetalWidthCm<br />
# dtype: float64</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# <th><blockquote>
# <p>75.500000<br />
# 5.843333<br />
# 3.054000<br />
# 3.758667<br />
# 1.198667</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 1
#
# \[55\]: print(df.loc\[:,'SepalLengthCm'\].mean())
#
# > 5.843333333333334
#
# \[16\]: print(df.loc\[:,'PetalLengthCm'\].mean())
#
# > 3.758666666666666
#
# \[19\]: df.mean(axis = 1, numeric_only=**True** )\[0:5\]
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>[19]: 0</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>2.24</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>1</td>
# <td><blockquote>
# <p>2.30</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>2</td>
# <td><blockquote>
# <p>2.48</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>3</td>
# <td><blockquote>
# <p>2.68</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>4</td>
# <td><blockquote>
# <p>3.04</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td colspan="2"><blockquote>
# <p>dtype: float64</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# \[59\]: df.median(numeric_only = "True" )
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>[59]: Id</p>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>SepalLengthCm SepalWidthCm<br />
# PetalLengthCm PetalWidthCm<br />
# dtype: float64</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# <th><blockquote>
# <p>75.50<br />
# 5.80<br />
# 3.00<br />
# 4.35<br />
# 1.30</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[22\]: print(df.loc\[:,'SepalLengthCm'\].median())
#
# > 5.8
#
# \[23\]: print(df.loc\[:,'PetalLengthCm'\].median())
#
# > 4.35
#
# \[30\]: df.median(axis = 1, numeric_only=**True** )\[0:5\]
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>[30]: 0</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1.4</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>1</td>
# <td><blockquote>
# <p>2.0</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>2</td>
# <td><blockquote>
# <p>3.0</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>3</td>
# <td><blockquote>
# <p>3.1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>4</td>
# <td><blockquote>
# <p>3.6</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td colspan="2"><blockquote>
# <p>dtype: float64</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# \[66\]: df.mode()
#
# <table>
# <colgroup>
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th rowspan="3">[66]:</th>
# <th rowspan="2"><blockquote>
# <p>0</p>
# </blockquote></th>
# <th>Id</th>
# <th>SepalLengthCm</th>
# <th>SepalWidthCm</th>
# <th>PetalLengthCm</th>
# <th>PetalWidthCm</th>
# <th rowspan="3"><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>\</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# <tr class="odd">
# <th>1</th>
# <th>5.0</th>
# <th>3.0</th>
# <th>1.5</th>
# <th>0.2</th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>1</p>
# </blockquote></th>
# <th>2</th>
# <th>NaN</th>
# <th>NaN</th>
# <th>NaN</th>
# <th>NaN</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 2
#
# <table>
# <colgroup>
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>2</p>
# </blockquote></th>
# <th>3</th>
# <th>NaN</th>
# <th rowspan="21">…</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# <th rowspan="21">…</th>
# <th>NaN</th>
# <th rowspan="21">…</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>3</p>
# </blockquote></th>
# <th>4</th>
# <th>NaN</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# <th>NaN</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>4</p>
# </blockquote></th>
# <th>5</th>
# <th>NaN</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# <th>NaN</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>..</p>
# </blockquote></th>
# <th><blockquote>
# <p>…</p>
# </blockquote></th>
# <th>…</th>
# <th rowspan="2"><blockquote>
# <p>NaN</p>
# </blockquote></th>
# <th rowspan="2">NaN</th>
# <th rowspan="2"><blockquote>
# <p>NaN</p>
# </blockquote></th>
# </tr>
# <tr class="header">
# <th>145</th>
# <th><blockquote>
# <p>146</p>
# </blockquote></th>
# <th>NaN</th>
# </tr>
# <tr class="odd">
# <th>146</th>
# <th><blockquote>
# <p>147</p>
# </blockquote></th>
# <th>NaN</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# <th>NaN</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# </tr>
# <tr class="header">
# <th>147</th>
# <th><blockquote>
# <p>148</p>
# </blockquote></th>
# <th>NaN</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# <th>NaN</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th>148</th>
# <th><blockquote>
# <p>149</p>
# </blockquote></th>
# <th>NaN</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# <th>NaN</th>
# <th><blockquote>
# <p>NaN</p>
# </blockquote></th>
# </tr>
# <tr class="header">
# <th>149</th>
# <th><blockquote>
# <p>150</p>
# </blockquote></th>
# <th>NaN</th>
# <th rowspan="13"><blockquote>
# <p>NaN</p>
# </blockquote></th>
# <th rowspan="13">NaN</th>
# <th rowspan="13"><blockquote>
# <p>NaN</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th rowspan="2"><blockquote>
# <p>0</p>
# </blockquote></th>
# <th colspan="2">Species</th>
# </tr>
# <tr class="header">
# <th colspan="2"><blockquote>
# <p>Iris-setosa</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>1</p>
# </blockquote></th>
# <th colspan="2"><blockquote>
# <p>Iris-versicolor</p>
# </blockquote></th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>2</p>
# </blockquote></th>
# <th colspan="2"><blockquote>
# <p>Iris-virginica</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>3</p>
# </blockquote></th>
# <th colspan="2">NaN</th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>4</p>
# </blockquote></th>
# <th colspan="2">NaN</th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>..</p>
# </blockquote></th>
# <th colspan="2">…</th>
# </tr>
# <tr class="header">
# <th>145</th>
# <th colspan="2">NaN</th>
# </tr>
# <tr class="odd">
# <th>146</th>
# <th colspan="2">NaN</th>
# </tr>
# <tr class="header">
# <th>147</th>
# <th colspan="2">NaN</th>
# </tr>
# <tr class="odd">
# <th>148</th>
# <th colspan="2">NaN</th>
# </tr>
# <tr class="header">
# <th>149</th>
# <th colspan="2">NaN</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > \[150 rows x 6 columns\]
#
# \[67\]: df.std(numeric_only = "True")
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>[67]: Id</p>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>SepalLengthCm SepalWidthCm<br />
# PetalLengthCm PetalWidthCm<br />
# dtype: float64</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# <th><blockquote>
# <p>43.445368<br />
# 0.828066<br />
# 0.433594<br />
# 1.764420<br />
# 0.763161</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[68\]: print(df.loc\[:,'SepalLengthCm'\].std())
#
# > 0.828066127977863
#
# \[34\]: print(df.loc\[:,'PetalLengthCm'\].std())
#
# > 1.7644204199522626
#
# \[35\]: df.std(axis = 1, numeric_only=**True** )\[0:5\]
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>[35]: 0 1 2</th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>2.010721<br />
# 1.772005<br />
# 1.754138</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 3
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>3</p>
# </blockquote></th>
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>1.813009</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>4</p>
# </blockquote></td>
# <td><blockquote>
# <p>2.165179</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td colspan="2"><blockquote>
# <p>dtype: float64</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# \[63\]: df.var(numeric_only = "True")
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>[63]: Id</p>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>SepalLengthCm SepalWidthCm<br />
# PetalLengthCm PetalWidthCm<br />
# dtype: float64</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# <th><blockquote>
# <p>1887.500000<br />
# 0.685694<br />
# 0.188004<br />
# 3.113179<br />
# 0.582414</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[37\]: **from scipy.stats import** iqr
#
# \[38\]: iqr(df\['SepalLengthCm'\])
#
# \[38\]:1.3000000000000007
#
# \[64\]: print(df.skew(numeric_only = " True" ))
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>Id<br />
# SepalLengthCm SepalWidthCm<br />
# PetalLengthCm PetalWidthCm<br />
# dtype: float64</th>
# <th>0.000000<br />
# 0.314911<br />
# 0.334053<br />
# -0.274464<br />
# -0.104997</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[41\]: df.describe()
#
# <table style="width:100%;">
# <colgroup>
# <col style="width: 14%" />
# <col style="width: 14%" />
# <col style="width: 14%" />
# <col style="width: 14%" />
# <col style="width: 14%" />
# <col style="width: 14%" />
# <col style="width: 14%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th rowspan="9">[41]:</th>
# <th rowspan="2">count</th>
# <th>Id</th>
# <th>SepalLengthCm</th>
# <th>SepalWidthCm</th>
# <th>PetalLengthCm</th>
# <th><blockquote>
# <p>PetalWidthCm</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th>150.000000</th>
# <th>150.000000</th>
# <th><blockquote>
# <p>150.000000</p>
# </blockquote></th>
# <th>150.000000</th>
# <th><blockquote>
# <p>150.000000</p>
# </blockquote></th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>mean</p>
# </blockquote></th>
# <th><blockquote>
# <p>75.500000</p>
# </blockquote></th>
# <th>5.843333</th>
# <th>3.054000</th>
# <th>3.758667</th>
# <th>1.198667</th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>std</p>
# </blockquote></th>
# <th><blockquote>
# <p>43.445368</p>
# </blockquote></th>
# <th>0.828066</th>
# <th>0.433594</th>
# <th>1.764420</th>
# <th>0.763161</th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>min</p>
# </blockquote></th>
# <th>1.000000</th>
# <th>4.300000</th>
# <th>2.000000</th>
# <th>1.000000</th>
# <th>0.100000</th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>25%</p>
# </blockquote></th>
# <th><blockquote>
# <p>38.250000</p>
# </blockquote></th>
# <th>5.100000</th>
# <th>2.800000</th>
# <th>1.600000</th>
# <th>0.300000</th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>50%</p>
# </blockquote></th>
# <th><blockquote>
# <p>75.500000</p>
# </blockquote></th>
# <th>5.800000</th>
# <th>3.000000</th>
# <th>4.350000</th>
# <th>1.300000</th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>75%</p>
# </blockquote></th>
# <th>112.750000</th>
# <th>6.400000</th>
# <th>3.300000</th>
# <th>5.100000</th>
# <th>1.800000</th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>max</p>
# </blockquote></th>
# <th>150.000000</th>
# <th>7.900000</th>
# <th>4.400000</th>
# <th>6.900000</th>
# <th>2.500000</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[42\]: df.describe(include='all')
#
# <table>
# <colgroup>
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# <col style="width: 12%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th rowspan="5">[42]:</th>
# <th rowspan="2"><blockquote>
# <p>count</p>
# </blockquote></th>
# <th>Id</th>
# <th>SepalLengthCm</th>
# <th>SepalWidthCm</th>
# <th>PetalLengthCm</th>
# <th>PetalWidthCm</th>
# <th rowspan="5">\</th>
# </tr>
# <tr class="odd">
# <th>150.000000</th>
# <th>150.000000</th>
# <th><blockquote>
# <p>150.000000</p>
# </blockquote></th>
# <th>150.000000</th>
# <th><blockquote>
# <p>150.000000</p>
# </blockquote></th>
# </tr>
# <tr class="header">
# <th>unique</th>
# <th>NaN</th>
# <th>NaN</th>
# <th>NaN</th>
# <th>NaN</th>
# <th>NaN</th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>top</p>
# </blockquote></th>
# <th>NaN</th>
# <th>NaN</th>
# <th>NaN</th>
# <th>NaN</th>
# <th>NaN</th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>freq</p>
# </blockquote></th>
# <th>NaN</th>
# <th>NaN</th>
# <th>NaN</th>
# <th>NaN</th>
# <th>NaN</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 4
#
# <table style="width:100%;">
# <colgroup>
# <col style="width: 16%" />
# <col style="width: 16%" />
# <col style="width: 16%" />
# <col style="width: 16%" />
# <col style="width: 16%" />
# <col style="width: 16%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>mean</p>
# </blockquote></th>
# <th><blockquote>
# <p>75.500000</p>
# </blockquote></th>
# <th>5.843333</th>
# <th>3.054000</th>
# <th>3.758667</th>
# <th><blockquote>
# <p>1.198667</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>std</p>
# </blockquote></td>
# <td><blockquote>
# <p>43.445368</p>
# </blockquote></td>
# <td>0.828066</td>
# <td>0.433594</td>
# <td>1.764420</td>
# <td><blockquote>
# <p>0.763161</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>min</p>
# </blockquote></td>
# <td><blockquote>
# <p>1.000000</p>
# </blockquote></td>
# <td>4.300000</td>
# <td>2.000000</td>
# <td>1.000000</td>
# <td><blockquote>
# <p>0.100000</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>25%</p>
# </blockquote></td>
# <td><blockquote>
# <p>38.250000</p>
# </blockquote></td>
# <td>5.100000</td>
# <td>2.800000</td>
# <td>1.600000</td>
# <td><blockquote>
# <p>0.300000</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>50%</p>
# </blockquote></td>
# <td><blockquote>
# <p>75.500000</p>
# </blockquote></td>
# <td>5.800000</td>
# <td>3.000000</td>
# <td>4.350000</td>
# <td><blockquote>
# <p>1.300000</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>75%</p>
# </blockquote></td>
# <td><blockquote>
# <p>112.750000</p>
# </blockquote></td>
# <td>6.400000</td>
# <td>3.300000</td>
# <td>5.100000</td>
# <td><blockquote>
# <p>1.800000</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>max</p>
# </blockquote></td>
# <td><blockquote>
# <p>150.000000</p>
# </blockquote></td>
# <td rowspan="13"><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>7.900000</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# <td rowspan="13">4.400000</td>
# <td rowspan="13">6.900000</td>
# <td rowspan="13"><blockquote>
# <p>2.500000</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td rowspan="2"><blockquote>
# <p>count</p>
# </blockquote></td>
# <td>Species</td>
# </tr>
# <tr class="even">
# <td>150</td>
# </tr>
# <tr class="odd">
# <td>unique</td>
# <td>3</td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>top</p>
# </blockquote></td>
# <td><blockquote>
# <p>Iris-setosa</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>freq</p>
# </blockquote></td>
# <td>50</td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>mean</p>
# </blockquote></td>
# <td>NaN</td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>std</p>
# </blockquote></td>
# <td>NaN</td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>min</p>
# </blockquote></td>
# <td>NaN</td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>25%</p>
# </blockquote></td>
# <td>NaN</td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>50%</p>
# </blockquote></td>
# <td>NaN</td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>75%</p>
# </blockquote></td>
# <td>NaN</td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>max</p>
# </blockquote></td>
# <td>NaN</td>
# </tr>
# </tbody>
# </table>
#
# 5
